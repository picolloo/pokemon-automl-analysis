# %% [markdown]
# <a href="https://colab.research.google.com/github/picolloo/pokemon-automl-analysis/blob/main/pokemon_automl_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

files.upload() #upload kaggle.json

# !pip install -q kaggle
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !ls ~/.kaggle
# !chmod 600 /root/.kaggle/kaggle.json
# Out:
#      <input type="file" id="files-367b2cd3-576f-4540-a8d1-3ea5b7bcb068" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-367b2cd3-576f-4540-a8d1-3ea5b7bcb068">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# kaggle.json

# %%
# !kaggle datasets download -d rounakbanik/pokemon
# !unzip pokemon.zip -d data
# Out:
# pokemon.zip: Skipping, found more recently modified local copy (use --force to force download)
# Archive:  pokemon.zip
#   inflating: data/pokemon.csv

# %%
import pandas as pd

# %%
df = pd.read_csv('data/pokemon.csv')
df.head()
# Out:
#                      abilities  against_bug  ...  generation  is_legendary
# 0  ['Overgrow', 'Chlorophyll']          1.0  ...           1             0
# 1  ['Overgrow', 'Chlorophyll']          1.0  ...           1             0
# 2  ['Overgrow', 'Chlorophyll']          1.0  ...           1             0
# 3     ['Blaze', 'Solar Power']          0.5  ...           1             0
# 4     ['Blaze', 'Solar Power']          0.5  ...           1             0
#
# [5 rows x 41 columns]

# %%
# !pip install pycaret

# %%
from pycaret import classification

# %%
to_remove = ['abilities','japanese_name', 'name', 'pokedex_number', 'generation']

# %%
ml_setup = classification.setup(data=df, 
                                  target='is_legendary', 
                                  ignore_features=to_remove,
                                  train_size=0.8, 
                                  session_id=1234
                                )
# Out:
#                                Description             Value
# 0                               session_id              1234
# 1                                   Target      is_legendary
# 2                              Target Type            Binary
# 3                            Label Encoded        0: 0, 1: 1
# 4                            Original Data         (801, 41)
# 5                           Missing Values              True
# 6                         Numeric Features                28
# 7                     Categorical Features                 7
# 8                         Ordinal Features             False
# 9                High Cardinality Features             False
# 10                 High Cardinality Method              None
# 11                   Transformed Train Set        (640, 607)
# 12                    Transformed Test Set        (161, 607)
# 13                      Shuffle Train-Test              True
# 14                     Stratify Train-Test             False
# 15                          Fold Generator   StratifiedKFold
# 16                             Fold Number                10
# 17                                CPU Jobs                -1
# 18                                 Use GPU             False
# 19                          Log Experiment             False
# 20                         Experiment Name  clf-default-name
# 21                                     USI              7236
# 22                         Imputation Type            simple
# 23          Iterative Imputation Iteration              None
# 24                         Numeric Imputer              mean
# 25      Iterative Imputation Numeric Model              None
# 26                     Categorical Imputer          constant
# 27  Iterative Imputation Categorical Model              None
# 28           Unknown Categoricals Handling    least_frequent
# 29                               Normalize             False
# 30                        Normalize Method              None
# 31                          Transformation             False
# 32                   Transformation Method              None
# 33                                     PCA             False
# 34                              PCA Method              None
# 35                          PCA Components              None
# 36                     Ignore Low Variance             False
# 37                     Combine Rare Levels             False
# 38                    Rare Level Threshold              None
# 39                         Numeric Binning             False
# 40                         Remove Outliers             False
# 41                      Outliers Threshold              None
# 42                Remove Multicollinearity             False
# 43             Multicollinearity Threshold              None
# 44                              Clustering             False
# 45                    Clustering Iteration              None
# 46                     Polynomial Features             False
# 47                       Polynomial Degree              None
# 48                    Trignometry Features             False
# 49                    Polynomial Threshold              None
# 50                          Group Features             False
# 51                       Feature Selection             False
# 52                Feature Selection Method           classic
# 53            Features Selection Threshold              None
# 54                     Feature Interaction             False
# 55                           Feature Ratio             False
# 56                   Interaction Threshold              None
# 57                           Fix Imbalance             False
# 58                    Fix Imbalance Method             SMOTE

# %%
best_model = classification.compare_models()
# Out:
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# dt               Decision Tree Classifier    0.9984  0.9991  1.0000  0.9857
# gbc          Gradient Boosting Classifier    0.9984  0.9991  1.0000  0.9857
# et                 Extra Trees Classifier    0.9984  0.9989  1.0000  0.9857
# rf               Random Forest Classifier    0.9969  0.9991  0.9833  0.9857
# ada                  Ada Boost Classifier    0.9969  0.9991  0.9833  0.9857
# ridge                    Ridge Classifier    0.9953  0.0000  0.9667  0.9857
# lightgbm  Light Gradient Boosting Machine    0.9953  0.9991  0.9667  0.9857
# lr                    Logistic Regression    0.9922  0.9951  0.9333  0.9857
# knn                K Neighbors Classifier    0.9594  0.9664  0.8548  0.7637
# nb                            Naive Bayes    0.9531  0.8994  0.8333  0.7511
# svm                   SVM - Linear Kernel    0.8641  0.0000  0.2143  0.3891
# lda          Linear Discriminant Analysis    0.7859  0.7250  0.6381  0.2547
# qda       Quadratic Discriminant Analysis    0.0953  0.5000  1.0000  0.0953
#
#               F1   Kappa     MCC  TT (Sec)
# dt        0.9923  0.9914  0.9918     0.044
# gbc       0.9923  0.9914  0.9918     0.428
# et        0.9923  0.9914  0.9918     0.488
# rf        0.9832  0.9815  0.9823     0.516
# ada       0.9832  0.9815  0.9823     0.223
# ridge     0.9741  0.9716  0.9728     0.081
# lightgbm  0.9741  0.9716  0.9728     0.142
# lr        0.9559  0.9517  0.9538     0.711
# knn       0.8012  0.7789  0.7837     0.158
# nb        0.7777  0.7521  0.7607     0.044
# svm       0.1791  0.1462  0.1979     0.056
# lda       0.3579  0.2590  0.3027     0.151
# qda       0.1740  0.0000  0.0000     0.129
